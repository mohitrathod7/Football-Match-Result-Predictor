# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np

# %%
path = './matches.csv'

# %%
matches = pd.read_csv(path, index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %% [markdown]
# We have 1389 matches count

# %% [markdown]
# # Understanding Data

# %%
# 38 matches each season, 20 teams, we have data of 2 seasons
38 * 20 * 2
# Out:
# 1520

# %%
# Get total matches for each team
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
'''In EPL, each year 3 teams are demoted to lower league and 3 teams are promoted to EPL from lower league.
So we will expect 6 teams will have lower count of matches but we have here 7 teams with less matches
So, first we will look Liverpool data to know what is going on.'''

matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %% [markdown]
# So we have data for Liverpool from 2020 to 2021 and missing data for next season.

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %% [markdown]
# We should have 40 matches per week but we dont have Liverpool another season data so it will be 39 which is fine.
# But we can see some Matchweeks has less matches so we know now where data is missing.

# %% [markdown]
# # Cleaning Data

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %% [markdown]
# ML algorithms cannot work with "object" data so we need to convert object to numeric predictors.

# %%
# Convert existing date column to datetime column
matches["date"] = pd.to_datetime(matches["date"])

# %% [markdown]
# # Creating Predictor variables

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
# time is 16:30, we will remove :30 and keep only 16, and convert to integer
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
# Monday: 0 ... Sunday: 6
matches["day_code"] = matches["date"].dt.dayofweek

# %%
# Win: 1 and Loss,Draw: 0
matches["target"] = (matches["result"] == "W").astype("int")

# %% [markdown]
# # Modeling

# %% [markdown]
# > This algorithm can pickup non-linearities in data. It is a series of decision trees, higher number of tress (n_estimators) more accuracy and more time to run.
#
# > For example, Opponent code 12 or 16 does not mean that opponent 16 is more difficult opponent 12, it is just a code for the opponents.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# random_state = 1 means we will get same results any time we run this as long as the data is same
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
# Generate predictions from test data
preds = rf.predict(test[predictors])

# %% [markdown]
# Now we will determine accuracy of the model

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ```
# from sklearn.metrics import accuracy_score
# ```
# accuracy_score will tell if we predicted the "WIN", what percentage of time did the team actually "WIN" and vice-versa

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6123188405797102

# %% [markdown]
# ## In which situations accuracy was high or low

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %% [markdown]
# We need to revise accuracy metrics

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %% [markdown]
# # Improving accuracy of the model

# %% [markdown]
# To improve accuracy we will look into more recent averages of the team such as:
#
# Compute rolling averages, how the team did in past few games, how many goals were scored against them, etc.
#
# Suppose if we are in week 4 for Manchester city, so we need to know how did the team performed in 3 weeks before this week (like won all last 3 matches), and get average of it.

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# from views.functions import rolling_averages

# %% [markdown]
# gf: goals for
#
# ga: goals against
#
# sh: shots taken
#
# sot: shots on target
#
# dist: total distance each shot traveled
#
# fk: free kicks
#
# pk: penalty kicks
#
# pkatt: penalty kicks attempts

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
matches_rolling = matches_rolling.droplevel("team") # drop extra index level "team" by position 0
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
# Reset index from 0 to end
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %% [markdown]
# # Retraining our Model

# %%
def make_predictions(data, predictors):
  train = data[data["date"] < '2022-01-01']
  test = data[data["date"] > '2022-01-01']
  rf.fit(train[predictors], train["target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
  precision = precision_score(test["target"], preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.625

# %%
combined
# Out:
#       actual  prediction
# 55         0           0
# 56         1           0
# 57         1           0
# 58         1           1
# 59         1           1
# ...      ...         ...
# 1312       1           0
# 1313       0           0
# 1314       1           0
# 1315       0           0
# 1316       0           0
#
# [276 rows x 2 columns]

# %% [markdown]
# Combine two "combined"(left_index) and "matches_rolling"(right_index) dataframes by thier respective index numbers that is why it is =True

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
#       actual  prediction       date                     team       opponent  \
# 55         0           0 2022-01-23                  Arsenal        Burnley
# 56         1           0 2022-02-10                  Arsenal         Wolves
# 57         1           0 2022-02-19                  Arsenal      Brentford
# 58         1           1 2022-02-24                  Arsenal         Wolves
# 59         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1312       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0           0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# ...

# %% [markdown]
# # Combining Home and Away Predictions

# %% [markdown]
# To make team names consistent.

# %%
from typing import Mapping
class MissignDict(dict):
  __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}

mapping = MissignDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)
combined
# Out:
#       actual  prediction       date                     team       opponent  \
# 55         0           0 2022-01-23                  Arsenal        Burnley
# 56         1           0 2022-02-10                  Arsenal         Wolves
# 57         1           0 2022-02-19                  Arsenal      Brentford
# 58         1           1 2022-02-24                  Arsenal         Wolves
# 59         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1312       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0           0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 55        D  Arsenal
# ...

# %% [markdown]
# merge Match --> "Arsenel" vs "Burnley"
#
# by same **Date** to
#
# Match --> "Burnley" vs "Arsenel"

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             0 2022-01-23                  Arsenal
# 1           1             0 2022-02-10                  Arsenal
# 2           1             0 2022-02-19                  Arsenal
# 3           1             1 2022-02-24                  Arsenal
# 4           1             1 2022-03-06                  Arsenal
# ..        ...           ...        ...                      ...
# 257         1             0 2022-03-13  Wolverhampton Wanderers
# 258         0             0 2022-03-18  Wolverhampton Wanderers
# 259         1             0 2022-04-02  Wolverhampton Wanderers
# 260         0             0 2022-04-08  Wolverhampton Wanderers
# 261         0             0 2022-04-24  Wolverhampton Wanderers
#
#         opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0          Burnley        D    Arsenal         0             0
# 1           Wolves        W    Arsenal         0             0
# ...

# %% [markdown]
# Sell all when model predicted **Team A** to Win and **Team B** to Lose and what actually happended.

# %%
true_positive_false_negative_counts = merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]['actual_x'].value_counts()
true_positive_false_negative_counts
# Out:
# actual_x
# 1    27
# 0    13
# Name: count, dtype: int64

# %%
new_accuracy = true_positive_false_negative_counts[1] / (true_positive_false_negative_counts.sum())
new_accuracy
# Out:
# 0.675

# %% [markdown]
# # All accuracies

# %%
print("acc:", str(round(acc*100, 2)) + "%")
print("precision:", str(round(precision*100, 2)) + "%")
print("new_accuracy:", str(round(new_accuracy*100, 3)) + "%")
# Out:
# acc: 61.23%
# precision: 62.5%
# new_accuracy: 67.5%

# %% [markdown]
# # Predict new match

# %% [markdown]
# Predicts the outcome of a new match based on the provided information.
#
# **Args:**
#
#     team: The name of the team.
#     opponent: The name of the opponent.
#     venue: The venue of the match ("Home" or "Away").
#     date: The date of the match as a string in YYYY-MM-DD format.
#     hour: The hour of the match.
#     rf_model: The trained RandomForestClassifier model.
#     predictors: The list of predictor variables.
#
# **Returns:**
#
#     A dictionary containing the predicted outcome (1 for win, 0 for loss/draw)
#     and the probabilities for win and loss/draw.

# %%
def predict_new_match_outcome(team, opponent, venue, date, hour, rf_model, predictors):
  team_data = matches_rolling[matches_rolling["team"] == team]
  team_data = team_data.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
  team_data = team_data.droplevel("team")
  team_data.index = range(team_data.shape[0])

  gf_rolling = team_data["gf_rolling"].iloc[-1]
  ga_rolling = team_data["ga_rolling"].iloc[-1]
  sh_rolling = team_data["sh_rolling"].iloc[-1]
  sot_rolling = team_data["sot_rolling"].iloc[-1]
  dist_rolling = team_data['dist_rolling'].iloc[-1]
  fk_rolling = team_data["fk_rolling"].iloc[-1]
  pk_rolling = team_data["pk_rolling"].iloc[-1]
  pkatt_rolling = team_data["pkatt_rolling"].iloc[-1]

  new_match = pd.DataFrame({
      'team': [team],
      'opponent': [opponent],
      'venue': [venue],
      'date': [pd.to_datetime(date)],
      'time': ['{hour}:00'.format(hour=hour)],
      'gf': [np.nan],
      'ga': [np.nan],
      'sh': [np.nan],
      'sot': [np.nan],
      'dist': [np.nan],
      'fk': [np.nan],
      'pk': [np.nan],
      'pkatt': [np.nan],
      'gf_rolling': [gf_rolling],
      'ga_rolling': [ga_rolling],
      'sh_rolling': [sh_rolling],
      'sot_rolling': [sot_rolling],
      'dist_rolling': [dist_rolling],
      'fk_rolling': [fk_rolling],
      'pk_rolling': [pk_rolling],
      'pkatt_rolling': [pkatt_rolling]
  })

  new_match["venue_code"] = new_match["venue"].astype("category").cat.codes
  new_match["opp_code"] = new_match["opponent"].astype("category").cat.codes
  new_match["hour"] = new_match["time"].str.replace(":.+", "", regex=True).astype("int")
  new_match["day_code"] = new_match["date"].dt.dayofweek

  prediction = rf_model.predict(new_match[predictors])
  probabilities = rf_model.predict_proba(new_match[predictors])

  return {
      'prediction': prediction[0],
      'win_probability': probabilities[0][1],
      'loss_draw_probability': probabilities[0][0],
  }

# %%
# Usage:
team_name = "Liverpool"
opponent_name = "Manchester"
venue_name = "Home"
match_date = "2023-11-18"
match_hour = 16

prediction_result = predict_new_match_outcome(
    team_name,
    opponent_name,
    venue_name,
    match_date,
    match_hour,
    rf,
    predictors + new_cols
)

print(prediction_result)
# Out:
# {'prediction': 1, 'win_probability': 0.6859560439560439, 'loss_draw_probability': 0.314043956043956}

# %%
pd.DataFrame(prediction_result, index=[0])
# Out:
#    prediction  win_probability  loss_draw_probability
# 0           1         0.685956               0.314044

# %% [markdown]
# # For importing model and variables to Flask app

# %%
# import pickle

# # Assuming 'model' is your trained machine learning model
# with open('model.pkl', 'wb') as f:
#     pickle.dump(rf, f)

# with open('model_variables.pkl', 'wb') as v:
#        pickle.dump((matches_rolling, rolling_averages), v)
